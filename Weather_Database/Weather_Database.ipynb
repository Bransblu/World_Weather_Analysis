# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config1 import weather_api_key
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a7f3ad6dac47c9a83c206e08c0000f6

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through the cities list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint url with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | magaria
# Processing Record 4 of Set 1 | vestmannaeyjar
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | qaqortoq
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | fortuna
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | katsuura
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | kargasok
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | cidreira
# Processing Record 17 of Set 1 | faanui
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | chalchihuites
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | vao
# Processing Record 22 of Set 1 | ahuimanu
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | sable-sur-sarthe
# Processing Record 25 of Set 1 | port macquarie
# Processing Record 26 of Set 1 | axim
# Processing Record 27 of Set 1 | ipixuna
# Processing Record 28 of Set 1 | oga
# Processing Record 29 of Set 1 | yashalta
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | mount gambier
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | cabedelo
# Processing Record 34 of Set 1 | manzanillo
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | lata
# Processing Record 37 of Set 1 | dingle
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | suclayin
# Processing Record 42 of Set 1 | turukhansk
# Processing Record 43 of Set 1 | arlit
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | havre de grace
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | baie-comeau
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | koryukivka
# Processing Record 1 of Set 2 | ormara
# Processing Record 2 of Set 2 | bandarbeyla
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | aswan
# Processing Record 5 of Set 2 | ponta delgada
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | porto novo
# Processing Record 10 of Set 2 | la ronge
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | zafarwal
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | mount isa
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | shahr-e kord
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | tuatapere
# Processing Record 19 of Set 2 | faya
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | kelo
# Processing Record 24 of Set 2 | sakakah
# Processing Record 25 of Set 2 | nhulunbuy
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | talnakh
# Processing Record 28 of Set 2 | tairua
# Processing Record 29 of Set 2 | alta floresta
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | kismayo
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | henties bay
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | sao geraldo do araguaia
# Processing Record 38 of Set 2 | jiupu
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | luau
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | mount pleasant
# Processing Record 44 of Set 2 | takoradi
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | hauterive
# Processing Record 47 of Set 2 | marawi
# Processing Record 48 of Set 2 | san cristobal
# Processing Record 49 of Set 2 | tura
# Processing Record 50 of Set 2 | anar darreh
# City not found. Skipping...
# Processing Record 1 of Set 3 | rafai
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | gezing
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | raudeberg
# Processing Record 7 of Set 3 | anadyr
# Processing Record 8 of Set 3 | naze
# Processing Record 9 of Set 3 | bonavista
# Processing Record 10 of Set 3 | tecoanapa
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | skelleftea
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | riverton
# Processing Record 15 of Set 3 | gubkinskiy
# Processing Record 16 of Set 3 | marzuq
# Processing Record 17 of Set 3 | mandalgovi
# Processing Record 18 of Set 3 | vaini
# Processing Record 19 of Set 3 | pacora
# Processing Record 20 of Set 3 | gushikawa
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | chapais
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | amazar
# Processing Record 26 of Set 3 | broome
# Processing Record 27 of Set 3 | ostrovnoy
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | hualmay
# Processing Record 30 of Set 3 | nouakchott
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | kon tum
# Processing Record 33 of Set 3 | mosquera
# Processing Record 34 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 3 | hambantota
# Processing Record 36 of Set 3 | laguna
# Processing Record 37 of Set 3 | isoka
# Processing Record 38 of Set 3 | calbuco
# Processing Record 39 of Set 3 | marquette
# Processing Record 40 of Set 3 | longyearbyen
# Processing Record 41 of Set 3 | visby
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | jingdezhen
# Processing Record 44 of Set 3 | matara
# Processing Record 45 of Set 3 | prieska
# Processing Record 46 of Set 3 | mackenzie
# Processing Record 47 of Set 3 | maniitsoq
# Processing Record 48 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | ndioum
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | kandiari
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | ordzhonikidze
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | saint-georges
# Processing Record 12 of Set 4 | mildura
# Processing Record 13 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 4 | lompoc
# Processing Record 15 of Set 4 | champasak
# Processing Record 16 of Set 4 | lavrentiya
# Processing Record 17 of Set 4 | viamao
# Processing Record 18 of Set 4 | aradippou
# Processing Record 19 of Set 4 | kumba
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | ayagoz
# Processing Record 22 of Set 4 | abu zabad
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | santiago
# Processing Record 25 of Set 4 | zhigansk
# Processing Record 26 of Set 4 | bagdarin
# Processing Record 27 of Set 4 | saint-joseph
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | ambilobe
# Processing Record 30 of Set 4 | kamenka
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 4 | roebourne
# Processing Record 34 of Set 4 | galle
# Processing Record 35 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | moose factory
# Processing Record 37 of Set 4 | praia
# Processing Record 38 of Set 4 | guane
# Processing Record 39 of Set 4 | fallon
# Processing Record 40 of Set 4 | whitehorse
# Processing Record 41 of Set 4 | montepuez
# Processing Record 42 of Set 4 | villa constitucion
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | ahipara
# Processing Record 45 of Set 4 | oktyabrskoye
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 4 | ancud
# Processing Record 48 of Set 4 | le vauclin
# Processing Record 49 of Set 4 | tromso
# Processing Record 50 of Set 4 | pokhara
# Processing Record 1 of Set 5 | tres lagoas
# Processing Record 2 of Set 5 | bazarnyye mataki
# Processing Record 3 of Set 5 | cherskiy
# Processing Record 4 of Set 5 | pacific grove
# Processing Record 5 of Set 5 | belmonte
# Processing Record 6 of Set 5 | asau
# Processing Record 7 of Set 5 | pingliang
# Processing Record 8 of Set 5 | torbay
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5 | lagoa
# Processing Record 11 of Set 5 | arman
# Processing Record 12 of Set 5 | rawson
# Processing Record 13 of Set 5 | zyryanka
# Processing Record 14 of Set 5 | leningradskiy
# Processing Record 15 of Set 5 | chegdomyn
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | bjornevatn
# Processing Record 18 of Set 5 | iqaluit
# Processing Record 19 of Set 5 | berlevag
# Processing Record 20 of Set 5 | shenjiamen
# Processing Record 21 of Set 5 | rivera
# Processing Record 22 of Set 5 | cabras
# Processing Record 23 of Set 5 | qobustan
# Processing Record 24 of Set 5 | saint-pierre
# Processing Record 25 of Set 5 | hami
# Processing Record 26 of Set 5 | lisakovsk
# Processing Record 27 of Set 5 | pevek
# Processing Record 28 of Set 5 | samarai
# Processing Record 29 of Set 5 | bogotol
# Processing Record 30 of Set 5 | miedzychod
# Processing Record 31 of Set 5 | machico
# Processing Record 32 of Set 5 | mehamn
# Processing Record 33 of Set 5 | komsomolskiy
# Processing Record 34 of Set 5 | shirokiy
# Processing Record 35 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 5 | ca mau
# Processing Record 37 of Set 5 | kirakira
# Processing Record 38 of Set 5 | amga
# Processing Record 39 of Set 5 | pathein
# Processing Record 40 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 41 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 42 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 5 | poum
# Processing Record 44 of Set 5 | mumford
# Processing Record 45 of Set 5 | powell
# Processing Record 46 of Set 5 | kutahya
# Processing Record 47 of Set 5 | airai
# Processing Record 48 of Set 5 | pudozh
# Processing Record 49 of Set 5 | dolgoye
# Processing Record 50 of Set 5 | prince rupert
# Processing Record 1 of Set 6 | ucluelet
# Processing Record 2 of Set 6 | cayenne
# Processing Record 3 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 6 | boysun
# Processing Record 7 of Set 6 | melo
# Processing Record 8 of Set 6 | port elizabeth
# Processing Record 9 of Set 6 | swan hill
# Processing Record 10 of Set 6 | mweka
# Processing Record 11 of Set 6 | nizwa
# Processing Record 12 of Set 6 | navirai
# Processing Record 13 of Set 6 | paka
# Processing Record 14 of Set 6 | opuwo
# Processing Record 15 of Set 6 | fos-sur-mer
# Processing Record 16 of Set 6 | vila franca do campo
# Processing Record 17 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 6 | san patricio
# Processing Record 19 of Set 6 | portsoy
# Processing Record 20 of Set 6 | stargard szczecinski
# Processing Record 21 of Set 6 | beira
# Processing Record 22 of Set 6 | durban
# Processing Record 23 of Set 6 | qasigiannguit
# Processing Record 24 of Set 6 | luderitz
# Processing Record 25 of Set 6 | challapata
# Processing Record 26 of Set 6 | pulivendla
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | butembo
# Processing Record 29 of Set 6 | buala
# Processing Record 30 of Set 6 | ewa beach
# Processing Record 31 of Set 6 | whyalla
# Processing Record 32 of Set 6 | ulaanbaatar
# Processing Record 33 of Set 6 | casper
# Processing Record 34 of Set 6 | beringovskiy
# Processing Record 35 of Set 6 | yablonovo
# Processing Record 36 of Set 6 | angoche
# Processing Record 37 of Set 6 | jumla
# Processing Record 38 of Set 6 | calvia
# Processing Record 39 of Set 6 | channel-port aux basques
# Processing Record 40 of Set 6 | kenai
# Processing Record 41 of Set 6 | aklavik
# Processing Record 42 of Set 6 | luwuk
# Processing Record 43 of Set 6 | sioni
# Processing Record 44 of Set 6 | sharjah
# Processing Record 45 of Set 6 | camacha
# Processing Record 46 of Set 6 | padang
# Processing Record 47 of Set 6 | forbes
# Processing Record 48 of Set 6 | gol
# Processing Record 49 of Set 6 | westport
# Processing Record 50 of Set 6 | nouadhibou
# Processing Record 1 of Set 7 | kaura namoda
# Processing Record 2 of Set 7 | hobyo
# Processing Record 3 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 7 | datong
# Processing Record 5 of Set 7 | nome
# Processing Record 6 of Set 7 | dudinka
# Processing Record 7 of Set 7 | coatlan
# City not found. Skipping...
# Processing Record 8 of Set 7 | omboue
# Processing Record 9 of Set 7 | beloha
# Processing Record 10 of Set 7 | cap malheureux
# Processing Record 11 of Set 7 | malpe
# Processing Record 12 of Set 7 | palembang
# Processing Record 13 of Set 7 | buta
# Processing Record 14 of Set 7 | okhotsk
# Processing Record 15 of Set 7 | sao filipe
# Processing Record 16 of Set 7 | ulaangom
# Processing Record 17 of Set 7 | masasi
# Processing Record 18 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 7 | lovozero
# Processing Record 20 of Set 7 | puerto madryn
# Processing Record 21 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 7 | shimoda
# Processing Record 23 of Set 7 | saint-augustin
# Processing Record 24 of Set 7 | vredendal
# Processing Record 25 of Set 7 | llanes
# Processing Record 26 of Set 7 | mercedes
# Processing Record 27 of Set 7 | rio gallegos
# Processing Record 28 of Set 7 | meulaboh
# Processing Record 29 of Set 7 | bengkulu
# Processing Record 30 of Set 7 | jaramana
# City not found. Skipping...
# Processing Record 31 of Set 7 | kyshtovka
# Processing Record 32 of Set 7 | manvi
# Processing Record 33 of Set 7 | lovendegem
# Processing Record 34 of Set 7 | hamilton
# Processing Record 35 of Set 7 | termini imerese
# Processing Record 36 of Set 7 | norman wells
# Processing Record 37 of Set 7 | taltal
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | broken hill
# Processing Record 40 of Set 7 | shunyi
# Processing Record 41 of Set 7 | atuona
# Processing Record 42 of Set 7 | alofi
# Processing Record 43 of Set 7 | flinders
# Processing Record 44 of Set 7 | sovetskiy
# Processing Record 45 of Set 7 | lahij
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | narsaq
# Processing Record 48 of Set 7 | virginia beach
# Processing Record 49 of Set 7 | zhuanghe
# Processing Record 50 of Set 7 | bonthe
# Processing Record 1 of Set 8 | erdenet
# Processing Record 2 of Set 8 | yaroslavskaya
# Processing Record 3 of Set 8 | oranjestad
# Processing Record 4 of Set 8 | bayir
# Processing Record 5 of Set 8 | ninghai
# Processing Record 6 of Set 8 | quelimane
# Processing Record 7 of Set 8 | okha
# Processing Record 8 of Set 8 | aykhal
# Processing Record 9 of Set 8 | mana
# Processing Record 10 of Set 8 | kachug
# Processing Record 11 of Set 8 | bathsheba
# Processing Record 12 of Set 8 | oranjemund
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | walvis bay
# Processing Record 15 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 8 | tekirdag
# Processing Record 17 of Set 8 | hithadhoo
# Processing Record 18 of Set 8 | paamiut
# Processing Record 19 of Set 8 | hayvoron
# Processing Record 20 of Set 8 | samarinda
# Processing Record 21 of Set 8 | kaduna
# Processing Record 22 of Set 8 | nuuk
# Processing Record 23 of Set 8 | kota kinabalu
# Processing Record 24 of Set 8 | kuusamo
# Processing Record 25 of Set 8 | lasa
# Processing Record 26 of Set 8 | kavieng
# Processing Record 27 of Set 8 | jalu
# Processing Record 28 of Set 8 | rusne
# Processing Record 29 of Set 8 | dolores
# Processing Record 30 of Set 8 | haines junction
# Processing Record 31 of Set 8 | san policarpo
# Processing Record 32 of Set 8 | kichera
# Processing Record 33 of Set 8 | przasnysz
# Processing Record 34 of Set 8 | porecatu
# Processing Record 35 of Set 8 | guerrero negro
# Processing Record 36 of Set 8 | chirongui
# Processing Record 37 of Set 8 | flin flon
# Processing Record 38 of Set 8 | brzeg
# Processing Record 39 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 8 | imphal
# Processing Record 41 of Set 8 | srednekolymsk
# Processing Record 42 of Set 8 | danielskuil
# Processing Record 43 of Set 8 | abong mbang
# Processing Record 44 of Set 8 | victoria
# Processing Record 45 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 8 | tiznit
# Processing Record 48 of Set 8 | spearfish
# Processing Record 49 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 1 of Set 9 | aleksandrovskoye
# Processing Record 2 of Set 9 | kahului
# Processing Record 3 of Set 9 | baykit
# Processing Record 4 of Set 9 | homagama
# Processing Record 5 of Set 9 | grindavik
# Processing Record 6 of Set 9 | angat
# Processing Record 7 of Set 9 | geraldton
# Processing Record 8 of Set 9 | hokitika
# Processing Record 9 of Set 9 | bhimavaram
# Processing Record 10 of Set 9 | kamaishi
# Processing Record 11 of Set 9 | clyde river
# Processing Record 12 of Set 9 | acari
# Processing Record 13 of Set 9 | hovd
# Processing Record 14 of Set 9 | adrar
# Processing Record 15 of Set 9 | alyangula
# Processing Record 16 of Set 9 | santa maria
# Processing Record 17 of Set 9 | jackson
# Processing Record 18 of Set 9 | marshall
# Processing Record 19 of Set 9 | talara
# Processing Record 20 of Set 9 | aasiaat
# Processing Record 21 of Set 9 | makakilo city
# Processing Record 22 of Set 9 | coahuayana
# Processing Record 23 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 9 | tondano
# Processing Record 25 of Set 9 | port lincoln
# Processing Record 26 of Set 9 | carballo
# Processing Record 27 of Set 9 | muli
# Processing Record 28 of Set 9 | sorong
# Processing Record 29 of Set 9 | erenhot
# Processing Record 30 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 9 | aquiraz
# Processing Record 32 of Set 9 | svetlogorsk
# Processing Record 33 of Set 9 | shingu
# Processing Record 34 of Set 9 | tucuma
# Processing Record 35 of Set 9 | vostok
# Processing Record 36 of Set 9 | tommot
# Processing Record 37 of Set 9 | dimitrovgrad
# Processing Record 38 of Set 9 | ampanihy
# Processing Record 39 of Set 9 | grand island
# Processing Record 40 of Set 9 | maraa
# Processing Record 41 of Set 9 | itacarambi
# Processing Record 42 of Set 9 | ribeira grande
# Processing Record 43 of Set 9 | davila
# Processing Record 44 of Set 9 | caravelas
# Processing Record 45 of Set 9 | sept-iles
# Processing Record 46 of Set 9 | nyurba
# Processing Record 47 of Set 9 | zhangjiakou
# Processing Record 48 of Set 9 | codrington
# Processing Record 49 of Set 9 | coalcoman
# City not found. Skipping...
# Processing Record 50 of Set 9 | banjar
# Processing Record 1 of Set 10 | livno
# Processing Record 2 of Set 10 | havelock
# Processing Record 3 of Set 10 | abha
# Processing Record 4 of Set 10 | prudentopolis
# Processing Record 5 of Set 10 | kayes
# Processing Record 6 of Set 10 | mendi
# Processing Record 7 of Set 10 | ust-tsilma
# Processing Record 8 of Set 10 | pochutla
# Processing Record 9 of Set 10 | apatou
# Processing Record 10 of Set 10 | carutapera
# Processing Record 11 of Set 10 | mitu
# Processing Record 12 of Set 10 | general roca
# Processing Record 13 of Set 10 | suntar
# Processing Record 14 of Set 10 | puerto escondido
# Processing Record 15 of Set 10 | hofn
# Processing Record 16 of Set 10 | sola
# Processing Record 17 of Set 10 | fairbanks
# Processing Record 18 of Set 10 | te anau
# Processing Record 19 of Set 10 | la asuncion
# Processing Record 20 of Set 10 | buraydah
# Processing Record 21 of Set 10 | nacala
# Processing Record 22 of Set 10 | lingao
# Processing Record 23 of Set 10 | cascais
# Processing Record 24 of Set 10 | kununurra
# Processing Record 25 of Set 10 | seoul
# Processing Record 26 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 10 | novita
# Processing Record 28 of Set 10 | dali
# Processing Record 29 of Set 10 | aanekoski
# Processing Record 30 of Set 10 | fremont
# Processing Record 31 of Set 10 | udachnyy
# Processing Record 32 of Set 10 | tessalit
# Processing Record 33 of Set 10 | havre-saint-pierre
# Processing Record 34 of Set 10 | taksimo
# Processing Record 35 of Set 10 | charlestown
# Processing Record 36 of Set 10 | guerrero
# Processing Record 37 of Set 10 | uwajima
# Processing Record 38 of Set 10 | kabalo
# Processing Record 39 of Set 10 | mutoko
# Processing Record 40 of Set 10 | esil
# Processing Record 41 of Set 10 | pouebo
# Processing Record 42 of Set 10 | hailar
# Processing Record 43 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 10 | mersing
# Processing Record 45 of Set 10 | ukiah
# Processing Record 46 of Set 10 | los llanos de aridane
# Processing Record 47 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 10 | sandy bay
# Processing Record 49 of Set 10 | husavik
# Processing Record 50 of Set 10 | sabzevar
# Processing Record 1 of Set 11 | kutum
# Processing Record 2 of Set 11 | mayari
# City not found. Skipping...
# Processing Record 3 of Set 11 | hay river
# Processing Record 4 of Set 11 | chizhou
# Processing Record 5 of Set 11 | nabire
# Processing Record 6 of Set 11 | kardymovo
# Processing Record 7 of Set 11 | marsh harbour
# Processing Record 8 of Set 11 | khanpur
# Processing Record 9 of Set 11 | blagoveshchensk
# Processing Record 10 of Set 11 | fare
# Processing Record 11 of Set 11 | ekhabi
# Processing Record 12 of Set 11 | ouadda
# Processing Record 13 of Set 11 | coihaique
# Processing Record 14 of Set 11 | kissidougou
# Processing Record 15 of Set 11 | asadabad
# Processing Record 16 of Set 11 | gat
# Processing Record 17 of Set 11 | truro
# Processing Record 18 of Set 11 | itoman
# Processing Record 19 of Set 11 | chara
# Processing Record 20 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 11 | stanisic
# Processing Record 22 of Set 11 | touros
# Processing Record 23 of Set 11 | portland
# Processing Record 24 of Set 11 | jamiltepec
# Processing Record 25 of Set 11 | nandu
# Processing Record 26 of Set 11 | ketchikan
# Processing Record 27 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 11 | caraquet
# Processing Record 29 of Set 11 | tezu
# Processing Record 30 of Set 11 | antsohihy
# Processing Record 31 of Set 11 | antofagasta
# Processing Record 32 of Set 11 | brufut
# Processing Record 33 of Set 11 | nyaunglebin
# Processing Record 34 of Set 11 | naron
# Processing Record 35 of Set 11 | saint george
# Processing Record 36 of Set 11 | kieta
# Processing Record 37 of Set 11 | kiama
# Processing Record 38 of Set 11 | fort nelson
# Processing Record 39 of Set 11 | nicolas bravo
# Processing Record 40 of Set 11 | jiazi
# Processing Record 41 of Set 11 | salatig
# Processing Record 42 of Set 11 | hengshui
# Processing Record 43 of Set 11 | mangrol
# Processing Record 44 of Set 11 | bengkalis
# City not found. Skipping...
# Processing Record 45 of Set 11 | kadaya
# Processing Record 46 of Set 11 | palana
# Processing Record 47 of Set 11 | sao felix do xingu
# Processing Record 48 of Set 11 | cockburn town
# Processing Record 49 of Set 11 | el jicaro
# Processing Record 50 of Set 11 | ambovombe
# Processing Record 1 of Set 12 | cabo san lucas
# Processing Record 2 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 12 | bose
# Processing Record 4 of Set 12 | enid
# Processing Record 5 of Set 12 | estelle
# Processing Record 6 of Set 12 | zhangye
# Processing Record 7 of Set 12 | qandala
# Processing Record 8 of Set 12 | xining
# Processing Record 9 of Set 12 | awjilah
# Processing Record 10 of Set 12 | vangaindrano
# Processing Record 11 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 12 | ugoofaaru
# Processing Record 13 of Set 12 | namibe
# Processing Record 14 of Set 12 | honiara
# Processing Record 15 of Set 12 | tabou
# Processing Record 16 of Set 12 | gravdal
# Processing Record 17 of Set 12 | paita
# Processing Record 18 of Set 12 | sorland
# Processing Record 19 of Set 12 | korla
# Processing Record 20 of Set 12 | belaya gora
# Processing Record 21 of Set 12 | willowmore
# Processing Record 22 of Set 12 | newton
# Processing Record 23 of Set 12 | bojaya
# City not found. Skipping...
# Processing Record 24 of Set 12 | kloulklubed
# Processing Record 25 of Set 12 | washington
# Processing Record 26 of Set 12 | byron bay
# Processing Record 27 of Set 12 | the valley
# Processing Record 28 of Set 12 | xapuri
# Processing Record 29 of Set 12 | campbeltown
# Processing Record 30 of Set 12 | javanrud
# Processing Record 31 of Set 12 | gagatli
# Processing Record 32 of Set 12 | lensk
# Processing Record 33 of Set 12 | freeport
# Processing Record 34 of Set 12 | miguel hidalgo
# Processing Record 35 of Set 12 | greece
# Processing Record 36 of Set 12 | ixtapa
# Processing Record 37 of Set 12 | aripuana
# Processing Record 38 of Set 12 | thinadhoo
# Processing Record 39 of Set 12 | lindas
# Processing Record 40 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 12 | inhambane
# Processing Record 42 of Set 12 | obo
# Processing Record 43 of Set 12 | nemuro
# Processing Record 44 of Set 12 | langholm
# Processing Record 45 of Set 12 | amzya
# Processing Record 46 of Set 12 | waitati
# Processing Record 47 of Set 12 | bac lieu
# Processing Record 48 of Set 12 | huntsville
# Processing Record 49 of Set 12 | luzilandia
# Processing Record 50 of Set 12 | kibuye
# Processing Record 1 of Set 13 | arraial do cabo
# Processing Record 2 of Set 13 | itaberai
# Processing Record 3 of Set 13 | aksha
# Processing Record 4 of Set 13 | deputatskiy
# Processing Record 5 of Set 13 | mocuba
# Processing Record 6 of Set 13 | malabo
# Processing Record 7 of Set 13 | awbari
# Processing Record 8 of Set 13 | tupik
# Processing Record 9 of Set 13 | maralal
# Processing Record 10 of Set 13 | fukue
# Processing Record 11 of Set 13 | xuanhua
# Processing Record 12 of Set 13 | waingapu
# Processing Record 13 of Set 13 | grande-riviere
# City not found. Skipping...
# Processing Record 14 of Set 13 | bukachacha
# Processing Record 15 of Set 13 | pervomayskoye
# Processing Record 16 of Set 13 | dutlwe
# Processing Record 17 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 13 | hvide sande
# Processing Record 19 of Set 13 | houston
# Processing Record 20 of Set 13 | ondjiva
# Processing Record 21 of Set 13 | guadalupe
# Processing Record 22 of Set 13 | araouane
# Processing Record 23 of Set 13 | burla
# Processing Record 24 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 13 | council bluffs
# Processing Record 26 of Set 13 | vanderhoof
# Processing Record 27 of Set 13 | orlik
# Processing Record 28 of Set 13 | humaita
# Processing Record 29 of Set 13 | kohlu
# Processing Record 30 of Set 13 | smolenka
# Processing Record 31 of Set 13 | uchana
# Processing Record 32 of Set 13 | tema
# Processing Record 33 of Set 13 | olafsvik
# Processing Record 34 of Set 13 | shaowu
# Processing Record 35 of Set 13 | atambua
# Processing Record 36 of Set 13 | viransehir
# Processing Record 37 of Set 13 | uthal
# Processing Record 38 of Set 13 | ushtobe
# Processing Record 39 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 40 of Set 13 | namatanai
# Processing Record 41 of Set 13 | kemijarvi
# Processing Record 42 of Set 13 | sukhumi
# Processing Record 43 of Set 13 | yining
# Processing Record 44 of Set 13 | honningsvag
# Processing Record 45 of Set 13 | cabo rojo
# Processing Record 46 of Set 13 | madaoua
# Processing Record 47 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 48 of Set 13 | qunduz
# Processing Record 49 of Set 13 | volga
# Processing Record 50 of Set 13 | vestmanna
# Processing Record 1 of Set 14 | homer
# Processing Record 2 of Set 14 | tateyama
# Processing Record 3 of Set 14 | emporia
# Processing Record 4 of Set 14 | jalesar
# Processing Record 5 of Set 14 | taoudenni
# Processing Record 6 of Set 14 | shakawe
# Processing Record 7 of Set 14 | panguna
# Processing Record 8 of Set 14 | starosubkhangulovo
# Processing Record 9 of Set 14 | asti
# Processing Record 10 of Set 14 | zyryanskoye
# Processing Record 11 of Set 14 | isangel
# Processing Record 12 of Set 14 | valparaiso
# Processing Record 13 of Set 14 | salym
# Processing Record 14 of Set 14 | paraiso
# Processing Record 15 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 14 | coquimbo
# Processing Record 17 of Set 14 | villaviciosa
# Processing Record 18 of Set 14 | lerik
# Processing Record 19 of Set 14 | zalari
# Processing Record 20 of Set 14 | requena
# Processing Record 21 of Set 14 | ust-omchug
# Processing Record 22 of Set 14 | muros
# Processing Record 23 of Set 14 | tambilil
# Processing Record 24 of Set 14 | chicama
# Processing Record 25 of Set 14 | erzin
# Processing Record 26 of Set 14 | patterson
# Processing Record 27 of Set 14 | bichena
# Processing Record 28 of Set 14 | kyzyl-suu
# Processing Record 29 of Set 14 | umm kaddadah
# Processing Record 30 of Set 14 | maxixe
# Processing Record 31 of Set 14 | west odessa
# Processing Record 32 of Set 14 | gloucester
# Processing Record 33 of Set 14 | mayumba
# Processing Record 34 of Set 14 | uto
# Processing Record 35 of Set 14 | matay
# Processing Record 36 of Set 14 | praia da vitoria
# Processing Record 37 of Set 14 | ambajogai
# Processing Record 38 of Set 14 | roald
# Processing Record 39 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 14 | togul
# Processing Record 41 of Set 14 | chengde
# Processing Record 42 of Set 14 | saint-paul
# Processing Record 43 of Set 14 | katete
# Processing Record 44 of Set 14 | karimganj
# Processing Record 45 of Set 14 | cuxhaven
# Processing Record 46 of Set 14 | caaguazu
# Processing Record 47 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 14 | lazurne
# Processing Record 49 of Set 14 | omutninsk
# Processing Record 50 of Set 14 | carnot
# Processing Record 1 of Set 15 | leh
# Processing Record 2 of Set 15 | turkistan
# Processing Record 3 of Set 15 | luanda
# Processing Record 4 of Set 15 | kashi
# Processing Record 5 of Set 15 | college
# Processing Record 6 of Set 15 | inhapim
# Processing Record 7 of Set 15 | dezful
# Processing Record 8 of Set 15 | niksar
# Processing Record 9 of Set 15 | hammerfest
# Processing Record 10 of Set 15 | misratah
# Processing Record 11 of Set 15 | estacion coahuila
# Processing Record 12 of Set 15 | dalbeattie
# Processing Record 13 of Set 15 | aliwal north
# Processing Record 14 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 15 of Set 15 | cumaral
# Processing Record 16 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 17 of Set 15 | sangmelima
# Processing Record 18 of Set 15 | bilma
# Processing Record 19 of Set 15 | tornio
# Processing Record 20 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 21 of Set 15 | dwarka
# Processing Record 22 of Set 15 | behshahr
# Processing Record 23 of Set 15 | makarov
# Processing Record 24 of Set 15 | kinablangan
# Processing Record 25 of Set 15 | port hardy
# Processing Record 26 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 15 | kupang
# Processing Record 28 of Set 15 | nara
# Processing Record 29 of Set 15 | vanimo
# Processing Record 30 of Set 15 | benghazi
# Processing Record 31 of Set 15 | nyzhni sirohozy
# Processing Record 32 of Set 15 | bud
# Processing Record 33 of Set 15 | comodoro rivadavia
# Processing Record 34 of Set 15 | demba
# Processing Record 35 of Set 15 | nantucket
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Souillac -20.5167   57.5167     73.78        94          75
# 1   Mar Del Plata -38.0023  -57.5575     59.88        76           0
# 2         Magaria  12.9983    8.9099     91.42        10          98
# 3  Vestmannaeyjar  63.4427  -20.2734     45.50        86          67
# 4       Esperance -33.8667  121.9000     67.84        42          99
# 5        Qaqortoq  60.7167  -46.0333     33.40        95          93
# 6         Ushuaia -54.8000  -68.3000     40.66        81          75
# 7         Fortuna  40.5982 -124.1573     59.94        80         100
# 8           Kapaa  22.0752 -159.3190     78.78        79          75
# 9    Kruisfontein -34.0033   24.7314     51.89        82           1
#
#    Wind Speed Country Current Description
# 0       11.50      MU       broken clouds
# 1        4.61      AR           clear sky
# 2        8.72      NE     overcast clouds
# 3       13.02      IS       broken clouds
# 4       17.27      AU     overcast clouds
# 5        3.85      GL     overcast clouds
# 6       18.41      AR       broken clouds
# 7       11.50      US     overcast clouds
# 8       17.27      US       broken clouds
# 9        6.87      ZA           clear sky

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df=city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
